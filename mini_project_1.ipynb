# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyajot70/Mini-Projects/blob/main/mini_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Converting coloured image to grayscale:

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Loading the image

# %%
#Colored Image
img = cv2.imread("/content/shoes - Copy.webp",1)
print(img.shape)
print(type(img))
#print(img)
# Out:
# (667, 1000, 3)
# <class 'numpy.ndarray'>

# %% [markdown]
# Displaying Image

# %%
from matplotlib import pyplot as plt

#Show the image with matplotlib
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7F512407F150>

# %% [markdown]
# Converting to Grayscale:

# %%
# Define our imshow function 
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imshow("Converted to Grayscale", gray_image)
